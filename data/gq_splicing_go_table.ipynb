# %%
import pandas as pd
import numpy as np
import os
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
os.path.abspath(".")
# Out:
# '/Users/gracequarterman/rasilab_spelman_2023/data'

# %%
data = pd.read_csv('gq_filtered_df_2.csv')

# %%
data
# Out:
#        GO term                                        Description
# 0   GO:0000398                     mRNA splicing, via spliceosome  \
# 1   GO:0000377  RNA splicing, via transesterification reaction...
# 2   GO:0000375    RNA splicing, via transesterification reactions
# 3   GO:0008380                                       RNA splicing
# 4   GO:0006397                                    mRNA processing
# ..         ...                                                ...
# 56  GO:0048002  antigen processing and presentation of peptide...
# 57  GO:0019882                antigen processing and presentation
# 58  GO:1905114  cell surface receptor signaling pathway involv...
# 59  GO:0016567                             protein ubiquitination
# 60  GO:0006283   transcription-coupled nucleotide-excision repair
#
#          P-value   FDR q-value Enrichment (N, B, n, b)           Genes
# 0   2.830000e-24  2.080000e-20   5.37 (2149,235,80,47)  [+] Show genes  \
# ...

# %%
df.drop(columns=['index', 'p-value'], inplace=True)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.drop(columns=['index', 'p-value'], inplace=True)
#       3 print(df.head())
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:5266, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5118 def drop(
#    5119     self,
#    5120     labels: IndexLabel = None,
#    (...)
#    5127     errors: IgnoreRaise = "raise",
#    5128 ) -> DataFrame | None:
#    5129     """
#    5130     Drop specified labels from rows or columns.
#    5131
#    (...)
#    5264             weight  1.0     0.8
#    5265     """
# -> 5266     return super().drop(
#    5267         labels=labels,
#    5268         axis=axis,
#    5269         index=index,
#    5270         columns=columns,
#    5271         level=level,
#    5272         inplace=inplace,
# ...

# %%
df = pd.DataFrame(data)

df_sorted_ascending = df.sort_values(by='FDR q-value', ascending=True)

df.head()
# Out:
#       GO term                                        Description
# 0  GO:0000398                     mRNA splicing, via spliceosome  \
# 1  GO:0000377  RNA splicing, via transesterification reaction...
# 2  GO:0000375    RNA splicing, via transesterification reactions
# 3  GO:0008380                                       RNA splicing
# 4  GO:0006397                                    mRNA processing
#
#         P-value   FDR q-value Enrichment (N, B, n, b)           Genes
# 0  2.830000e-24  2.080000e-20   5.37 (2149,235,80,47)  [+] Show genes  \
# 1  2.830000e-24  1.040000e-20   5.37 (2149,235,80,47)  [+] Show genes
# 2  6.510000e-24  1.590000e-20   5.28 (2149,239,80,47)  [+] Show genes
# 3  8.170000e-20  1.500000e-16   3.86 (2149,321,92,53)  [+] Show genes
# 4  6.700000e-17  9.860000e-14   3.57 (2149,369,80,49)  [+] Show genes
#
#    enrichment  Enrichment  Calculation1  Calculation2  Calculation3
# 0         5.0  5.37 (2149           NaN           235           NaN  \
# ...

# %%
df_sorted_ascending.rename(columns={'Calculation2': 'AssociatedGenes'}, inplace=True)

print(df_sorted_ascending.head())
# Out:
#       GO term                                        Description
# 1  GO:0000377  RNA splicing, via transesterification reaction...  \
# 2  GO:0000375    RNA splicing, via transesterification reactions
# 0  GO:0000398                     mRNA splicing, via spliceosome
# 3  GO:0008380                                       RNA splicing
# 4  GO:0006397                                    mRNA processing
#
#         P-value   FDR q-value Enrichment (N, B, n, b)           Genes
# 1  2.830000e-24  1.040000e-20   5.37 (2149,235,80,47)  [+] Show genes  \
# 2  6.510000e-24  1.590000e-20   5.28 (2149,239,80,47)  [+] Show genes
# 0  2.830000e-24  2.080000e-20   5.37 (2149,235,80,47)  [+] Show genes
# 3  8.170000e-20  1.500000e-16   3.86 (2149,321,92,53)  [+] Show genes
# 4  6.700000e-17  9.860000e-14   3.57 (2149,369,80,49)  [+] Show genes
#
#    enrichment  Enrichment  Calculation1  AssociatedGenes  Calculation3
# 1         5.0  5.37 (2149           NaN              235           NaN  \
# ...

# %%
columns_to_drop = ['Enrichment (N, B, n, b)','Genes','Enrichment','Calculation3','Calculation4']  

# Replace with the column names you want to remove
df_sorted_ascending.drop(columns=columns_to_drop, inplace=True)

print(df_sorted_ascending.head())
# Out:
#       GO term                                        Description
# 1  GO:0000377  RNA splicing, via transesterification reaction...  \
# 2  GO:0000375    RNA splicing, via transesterification reactions
# 0  GO:0000398                     mRNA splicing, via spliceosome
# 3  GO:0008380                                       RNA splicing
# 4  GO:0006397                                    mRNA processing
#
#     FDR q-value  enrichment  AssociatedGenes
# 1  1.040000e-20         5.0              235
# 2  1.590000e-20         5.0              239
# 0  2.080000e-20         5.0              235
# 3  1.500000e-16         4.0              321
# 4  9.860000e-14         4.0              369

# %%
df_sorted_ascending.to_csv('gq_splicing_go_table.csv', index=False)
