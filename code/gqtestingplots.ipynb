# %%
import pandas as pd
import numpy as np
import os
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
os.path.abspath(".")
# Out:
# '/Users/gracequarterman/rasilab_spelman_2023/code'

# %%
import pandas as pd
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv')

# %%
data
# Out:
#      id\tnum\tneg|score\tneg|p-value\tneg|fdr\tneg|rank\tneg|goodsgrna\tneg|lfc\tpos|score\tpos|p-value\tpos|fdr\tpos|rank\tpos|goodsgrna\tpos|lfc
# 0     AQR\t4\t1.0\t1.0\t0.999998\t2189\t0\t3.9439\t6...
# 1     CWC22\t4\t1.0\t1.0\t0.999998\t2188\t0\t2.9268\...
# 2     DHX38\t4\t1.0\t1.0\t0.999998\t2187\t0\t2.1742\...
# 3     CRNKL1\t4\t1.0\t1.0\t0.999998\t2186\t0\t2.1624...
# 4     DGCR14\t4\t1.0\t1.0\t0.999998\t2185\t0\t2.4018...
# ...                                                 ...
# 2184  SYMPK\t3\t0.00021085\t0.00072143\t0.143564\t11...
# 2185  SERBP1\t3\t0.00019258\t0.00068524\t0.143564\t1...
# 2186  ABCF1\t4\t3.9486e-05\t0.00013343\t0.058416\t5\...
# 2187  INTS8\t3\t3.4163e-05\t0.00012438\t0.058416\t4\...
# 2188  PDCD7\t4\t2.8881e-05\t8.82e-05\t0.058416\t3\t4...
#
# [2189 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
data = pd.read_table('../data/gq_mageck.gene_summary.tsv')

# %%
data.columns
# Out:
# Index(['id', 'num', 'neg|score', 'neg|p-value', 'neg|fdr', 'neg|rank',
#        'neg|goodsgrna', 'neg|lfc', 'pos|score', 'pos|p-value', 'pos|fdr',
#        'pos|rank', 'pos|goodsgrna', 'pos|lfc'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['num']
y = data['neg|score']

# %%
x
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 2184    3
# 2185    3
# 2186    4
# 2187    3
# 2188    4
# Name: num, Length: 2189, dtype: int64

# %%
plt.scatter(x,y)
plt.xlabel('num')
plt.ylabel('neg|score')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['neg|p-value']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('neg|p-value')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['neg|fdr']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('neg|fdr')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['neg|rank']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('neg|rank')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['neg|goodsgrna']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('neg|goodsgrna')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['neg|lfc']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('neg|lfc')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['pos|score']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('pos|score')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['pos|p-value']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('pos|p-value')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['pos|fdr']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('pos|fdr')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['pos|rank']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('pos|rank')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['pos|goodsgrna']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('pos|goodsgrna')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['neg|score']
y = data['pos|lfc']

# %%
plt.scatter(x,y)
plt.xlabel('neg|score')
plt.ylabel('pos|lfc')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['neg|p-value']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('neg|p-value')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['neg|fdr']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('neg|fdr')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['neg|rank']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('neg|rank')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['neg|goodsgrna']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('neg|goodsgrna')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['neg|lfc']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('neg|lfc')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['pos|p-value']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('pos|p-value')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['pos|fdr']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('pos|fdr')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['pos|rank']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('pos|rank')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['pos|goodsgrna']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('pos|goodsgrna')
plt.title('Data Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data from CSV
data = pd.read_csv('../data/gq_mageck.gene_summary.tsv', sep='\t')

# Access the columns of the dataset
x = data['pos|score']
y = data['pos|lfc']

# %%
plt.scatter(x,y)
plt.xlabel('pos|score')
plt.ylabel('pos|lfc')
plt.title('Data Plot')
plt.show()
